# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# %%
shuttle_train = pd.read_csv("shuttle.trn", sep=" ", header=None, names=('time','feat1','feat2','feat3','feat4','feat5','feat6','feat7','feat8','class'))

# %%
print(shuttle_train.shape)
print(shuttle_train.ndim)
shuttle_train.head()
# Out:
# (43500, 10)
# 2
#    time  feat1  feat2  feat3  feat4  feat5  feat6  feat7  feat8  class
# 0    50     21     77      0     28      0     27     48     22      2
# 1    55      0     92      0      0     26     36     92     56      4
# 2    53      0     82      0     52     -5     29     30      2      1
# 3    37      0     76      0     28     18     40     48      8      1
# 4    37      0     79      0     34    -26     43     46      2      1

# %%
shuttle_train.tail()
# Out:
#        time  feat1  feat2  feat3  feat4  feat5  feat6  feat7  feat8  class
# 43495    46      5     78      0     46      5     32     32      0      1
# 43496    37      0     79     -1     10      3     43     69     26      1
# 43497    48      0     78      3     46      0     30     32      2      1
# 43498    41      0     79      0     38    -25     38     40      2      1
# 43499    40     -3    100      0     38      0     61     62      2      1

# %%
shuttle_train['class'].nunique()
# Out:
# 7

# %%
shuttle_train.set_index('class')
shuttle_train.set_index('class').drop(4, axis=0)
# Out:
#        time  feat1  feat2  feat3  feat4  feat5  feat6  feat7  feat8
# class
# 2        50     21     77      0     28      0     27     48     22
# 1        53      0     82      0     52     -5     29     30      2
# 1        37      0     76      0     28     18     40     48      8
# 1        37      0     79      0     34    -26     43     46      2
# 5        85      0     88     -4      6      1      3     83     80
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1        46      5     78      0     46      5     32     32      0
# 1        37      0     79     -1     10      3     43     69     26
# 1        48      0     78      3     46      0     30     32      2
# 1        41      0     79      0     38    -25     38     40      2
# 1        40     -3    100      0     38      0     61     62      2
#
# [36752 rows x 9 columns]

# %%
shuttle_train = np.array(shuttle_train)

# %%
shuttle_train
# Out:
# array([[ 50,  21,  77, ...,  48,  22,   2],
#        [ 55,   0,  92, ...,  92,  56,   4],
#        [ 53,   0,  82, ...,  30,   2,   1],
#        ...,
#        [ 48,   0,  78, ...,  32,   2,   1],
#        [ 41,   0,  79, ...,  40,   2,   1],
#        [ 40,  -3, 100, ...,  62,   2,   1]])

# %%
cpu_util = pd.read_csv("NAB/data/realKnownCause/cpu_utilization_asg_misconfiguration.csv", sep=",",)

# %%
cpu_util['timestamp'] = pd.to_datetime(cpu_util['timestamp'], format="%Y-%m-%d %H:%M:%S")

# %%
cpu_util.head()
# Out:
#             timestamp   value
# 0 2014-05-14 01:14:00  85.835
# 1 2014-05-14 01:19:00  88.167
# 2 2014-05-14 01:24:00  44.595
# 3 2014-05-14 01:29:00  56.282
# 4 2014-05-14 01:34:00  36.534

# %%
cpu_util.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18050 entries, 0 to 18049
# Data columns (total 2 columns):
# timestamp    18050 non-null datetime64[ns]
# value        18050 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 282.2 KB

# %%
cpu_util['timestamp'].describe()
# Out:
# count                   18050
# unique                  18050
# top       2014-06-03 22:09:00
# freq                        1
# first     2014-05-14 01:14:00
# last      2014-07-15 17:19:00
# Name: timestamp, dtype: object

# %%
max(cpu_util['timestamp'])
# Out:
# Timestamp('2014-07-15 17:19:00')

# %%
cpu_util[['timestamp','value']].plot(kind='line', figsize = (20,6), xlim=('2014-05-14','2014-07-15'))

# %%
cpu_util[cpu_util['timestamp']>'2014-07-10'].plot(kind='line', figsize = (20,6))

# %%
cpu_util[cpu_util['timestamp']>'2014-07-12']
# Out:
#                  timestamp    value
# 16978  2014-07-12 00:04:00   45.699
# 16979  2014-07-12 00:09:00  100.000
# 16980  2014-07-12 00:14:00   93.559
# 16981  2014-07-12 00:19:00   30.310
# 16982  2014-07-12 00:24:00   29.114
# ...                    ...      ...
# 18045  2014-07-15 16:59:00   13.498
# 18046  2014-07-15 17:04:00   19.831
# 18047  2014-07-15 17:09:00   27.165
# 18048  2014-07-15 17:14:00   12.873
# 18049  2014-07-15 17:19:00   12.129
#
# [1072 rows x 2 columns]

# %%
#data preprocessing: define history window(w), threshold for anomaly, length of output(p_w)
#To determine the best combination, need to grid search
w = 45
thresh = 0.5
p_w = 1
filter_size_1 = 32
filter_size_2 = 32
kernel_size_1 = 2 # Not described in the paper
kernel_size_2 = 2 # Not described in the paper
max_pool_size_1 = 2 # Not described in the paper
max_pool_size_2 = 2 # Not described in the paper
FC_size = 30 # Not described in the paper

nFeatures = 1

# %%
for i in range(cpu_util.shape[0] - 45 + 1 - p_w):
    window = np.expand_dims(np.array(cpu_util['value'].iloc[i:i+w]), axis = 0)    
    label = np.expand_dims(cpu_util['value'].iloc[i+w:i+w+p_w], axis = 0)
    if i == 0:
        windows = window
        labels = label
    else:
        windows = np.append(windows, window, axis=0)
        labels = np.append(labels, label, axis = 0)

# %%
vector_x = np.expand_dims(windows, axis = -1) / 100
vector_x.shape
# Out:
# (18005, 45, 1)

# %%
y = np.expand_dims(cpu_util['value'].iloc[45:cpu_util.shape[0]],axis=-1) / 100
y.shape
# Out:
# (18005, 1)

# %%
from sklearn import model_selection

# %%
x_train, x_valid, y_train, y_valid = model_selection.train_test_split(vector_x, y,test_size=0.2)

# %%
model = tf.keras.Sequential([    
    layers.Conv1D(filter_size_1, kernel_size_1, activation='relu', input_shape=(w,nFeatures), padding='valid'),
    layers.MaxPooling1D(max_pool_size_1, strides=1, padding='same'),
    layers.Conv1D(filter_size_2, kernel_size_2, activation='relu', padding='same'),
    layers.Flatten(),
    layers.Dense(FC_size),
    layers.Dense(p_w)
])

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
            optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
            metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_43 (Conv1D)           (None, 44, 32)            96
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 44, 32)            0
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 44, 32)            2080
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 1408)              0
# _________________________________________________________________
# dense_39 (Dense)             (None, 30)                42270
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 44,477
# Trainable params: 44,477
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs = 10)
# Out:
# Train on 14404 samples
# Epoch 1/10
# 14404/14404 [==============================] - 3s 200us/sample - loss: 0.0135 - accuracy: 0.0173
# Epoch 2/10
# 14404/14404 [==============================] - 2s 154us/sample - loss: 0.0073 - accuracy: 0.0243
# Epoch 3/10
# 14404/14404 [==============================] - 2s 154us/sample - loss: 0.0060 - accuracy: 0.0244
# Epoch 4/10
# 14404/14404 [==============================] - 2s 152us/sample - loss: 0.0053 - accuracy: 0.0244
# Epoch 5/10
# 14404/14404 [==============================] - 2s 153us/sample - loss: 0.0049 - accuracy: 0.0244
# Epoch 6/10
# 14404/14404 [==============================] - 2s 151us/sample - loss: 0.0045 - accuracy: 0.0244
# Epoch 7/10
# 14404/14404 [==============================] - 2s 150us/sample - loss: 0.0043 - accuracy: 0.0244
# Epoch 8/10
# 14404/14404 [==============================] - 2s 155us/sample - loss: 0.0041 - accuracy: 0.0243
# Epoch 9/10
# 14404/14404 [==============================] - 2s 156us/sample - loss: 0.0039 - accuracy: 0.0243
# Epoch 10/10
# 14404/14404 [==============================] - 2s 154us/sample - loss: 0.0038 - accuracy: 0.0243

# %%
model.evaluate(x_valid, y_valid, verbose=2)
# Out:
# 3601/3601 - 0s - loss: 0.0038 - accuracy: 0.0183
# [0.003755618019005704, 0.018328242]

# %%
predictions=model.predict(x_valid)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,6))
plt.plot(y_valid[:500])
plt.plot(predictions[:500])
plt.show()
